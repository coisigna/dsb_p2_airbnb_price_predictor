# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("datasets/Software Industry Salary/Salary_Dataset_with_Extra_Features.csv")

# %%
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df.shape
# Out:
# (22770, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22770 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
df.describe().T
# Out:
#                      count           mean            std     min       25%  \
# Rating             22770.0       3.918213       0.519675     1.0       3.7
# Salary             22770.0  695387.211243  884399.013676  2112.0  300000.0
# Salaries Reported  22770.0       1.855775       6.823668     1.0       1.0
#
#                         50%       75%         max
# Rating                  3.9       4.2         5.0
# Salary             500000.0  900000.0  90000000.0
# Salaries Reported       1.0       1.0       361.0

# %%
df.columns
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location', 'Employment Status', 'Job Roles'],
#       dtype='object')

# %%
print(len(df["Rating"].unique()),df["Rating"].unique())
# Out:
# 41 [3.8  4.5  4.   4.4  4.2  3.7  3.1  3.6  3.9  4.8  4.1  4.3  4.9  5.
#  4.6  3.3  2.9  3.5  3.   1.   3.4  2.8  4.7  3.2  2.4  2.2  2.7  1.8
#  2.1  2.3  2.6  2.   1.4  1.5  2.5  1.7  1.9  1.6  3.95 1.3  3.85]

# %%
print(len(df["Company Name"].unique()),df["Company Name"].unique())
# Out:
# 11261 ['Sasken' 'Advanced Millennium Technologies' 'Unacademy' ...
#  'Unicon Systems' 'Expert Solutions' 'Nextgen Innovation Labs']

# %%
for i in df.columns:
    print(i)
    print("---"*30)
    print(len(df[i].unique()),df[i].unique())
    print("---" *30)
# Out:
# Rating
# ------------------------------------------------------------------------------------------
# 41 [3.8  4.5  4.   4.4  4.2  3.7  3.1  3.6  3.9  4.8  4.1  4.3  4.9  5.
#  4.6  3.3  2.9  3.5  3.   1.   3.4  2.8  4.7  3.2  2.4  2.2  2.7  1.8
#  2.1  2.3  2.6  2.   1.4  1.5  2.5  1.7  1.9  1.6  3.95 1.3  3.85]
# ------------------------------------------------------------------------------------------
# Company Name
# ------------------------------------------------------------------------------------------
# 11261 ['Sasken' 'Advanced Millennium Technologies' 'Unacademy' ...
#  'Unicon Systems' 'Expert Solutions' 'Nextgen Innovation Labs']
# ------------------------------------------------------------------------------------------
# Job Title
# ------------------------------------------------------------------------------------------
# 1080 ['Android Developer' 'Android Developer - Intern'
#  'Android Developer - Contractor' ... 'Web Developer Contractor'
# ...

# %%
sns.pairplot(df)

# %%
df_nums = df._get_numeric_data()

# %%
for i in df_nums.columns:
    
    print(i)
    sns.kdeplot(df_nums[i].unique())
    plt.show()
# Out:
# Rating
# Salary
# Salaries Reported

# %%
for i in df_nums.columns:
    print(i)
    sns.histplot(df[i])
    plt.show()
# Out:
# Rating
# Salary
# Salaries Reported
