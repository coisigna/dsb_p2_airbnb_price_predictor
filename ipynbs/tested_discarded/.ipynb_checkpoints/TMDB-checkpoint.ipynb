# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")

# %%
df_test = pd.read_csv("test.csv")

# %%
df_sample = pd.read_csv("sample_submission.csv")

# %%
df_test_sample = pd.merge(left= df_test, right= df_sample, on= "id")

# %%
df = pd.concat([df, df_test_sample], axis=0)

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 4393  7394                                                NaN  42000000
# 4394  7395  [{'id': 146534, 'name': 'Without a Paddle Coll...  19000000
# 4395  7396                                                NaN  16000000
# 4396  7397                                                NaN   2000000
# 4397  7398                                                NaN     64000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 4393                   [{'id': 53, 'name': 'Thriller'}]
# 4394  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4395                      [{'id': 18, 'name': 'Drama'}]
# 4396  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 4397                      [{'id': 18, 'name': 'Drama'}]
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 4393                                NaN  tt0218922                en
# 4394                                NaN  tt0364751                en
# 4395                                NaN  tt0084855                en
# 4396                                NaN  tt3235888                en
# 4397                                NaN  tt0056663                fr
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 4393                              Original Sin
# 4394                          Without a Paddle
# 4395                               The Verdict
# 4396                                It Follows
# 4397      Vivre sa vie: film en douze tableaux
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 4393  A young man is plunged into a life of subterfu...    9.970359  ...
# 4394  Three friends, whose lives have been drifting ...    6.046516  ...
# 4395  Frank Galvin is a down-on-his luck lawyer, red...    9.596883  ...
# 4396  For 19-year-old Jay, fall should be about scho...   20.359336  ...
# 4397  Twelve episodic tales in the life of a Parisia...   11.305910  ...
#
#      release_date runtime                                   spoken_languages  \
# 0         2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1          8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3          3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4          2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# ...           ...     ...                                                ...
# 4393       8/3/01   118.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4394      8/20/04    95.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4395      12/8/82   129.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4396       2/4/15   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4397      9/20/62    85.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
#
#         status                                            tagline  \
# 0     Released  The Laws of Space and Time are About to be Vio...
# 1     Released  It can take a lifetime to find true love; she'...
# 2     Released    The road to greatness can take you to the edge.
# 3     Released                                                NaN
# 4     Released                                                NaN
# ...        ...                                                ...
# 4393  Released  This is not a love story - it's a story about ...
# 4394  Released  The call of the wild, the thrill of adventure....
# 4395  Released  The doctors want to settle, the Church wants t...
# 4396  Released  It doesn't think, it doesn't feel, it doesn't ...
# 4397  Released  The many faces of a woman trying to find herse...
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 4393                              Original Sin
# 4394                          Without a Paddle
# 4395                               The Verdict
# 4396                                It Follows
# 4397                              Vivre Sa Vie
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 4393  [{'id': 515, 'name': 'women'}, {'id': 572, 'na...
# 4394  [{'id': 4959, 'name': 'death of a friend'}, {'...
# 4395  [{'id': 1680, 'name': 'boston'}, {'id': 6148, ...
# 4396  [{'id': 3713, 'name': 'chase'}, {'id': 6152, '...
# 4397  [{'id': 90, 'name': 'paris'}, {'id': 490, 'nam...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 4393  [{'cast_id': 17, 'character': 'Julia Russell/B...
# 4394  [{'cast_id': 40, 'character': 'Dan Mott', 'cre...
# 4395  [{'cast_id': 1, 'character': 'Frank Galvin', '...
# 4396  [{'cast_id': 1, 'character': 'Jay Height', 'cr...
# 4397  [{'cast_id': 8, 'character': 'Nana Kleinfranke...
#
#                                                    crew   revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# ...                                                 ...       ...
# 4393  [{'credit_id': '52fe4330c3a36847f80412db', 'de...   1000000
# 4394  [{'credit_id': '52fe43b29251416c7501a909', 'de...   1000000
# 4395  [{'credit_id': '52fe448bc3a368484e028c55', 'de...   1000000
# 4396  [{'credit_id': '537770b20e0a261431002299', 'de...   1000000
# 4397  [{'credit_id': '52fe4306c3a36847f80349a5', 'de...   1000000
#
# [7398 rows x 23 columns]

# %%
df.shape
# Out:
# (7398, 23)

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df.describe().T
# Out:
#              count          mean           std       min             25%  \
# id          7398.0  3.699500e+03  2.135763e+03  1.000000     1850.250000
# budget      7398.0  2.260146e+07  3.694867e+07  0.000000        0.000000
# popularity  7398.0  8.514968e+00  1.216579e+01  0.000001        3.933124
# runtime     7392.0  1.077173e+02  2.148004e+01  0.000000       94.000000
# revenue     7398.0  2.765282e+07  9.332953e+07  1.000000  1000000.000000
#
#                      50%           75%           max
# id          3.699500e+03  5.548750e+03  7.398000e+03
# budget      7.500000e+06  2.800000e+07  3.800000e+08
# popularity  7.435844e+00  1.092000e+01  5.474883e+02
# runtime     1.040000e+02  1.180000e+02  3.380000e+02
# revenue     1.000000e+06  8.025728e+06  1.519558e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7398 entries, 0 to 4397
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     7398 non-null   int64
#  1   belongs_to_collection  1481 non-null   object
#  2   budget                 7398 non-null   int64
#  3   genres                 7375 non-null   object
#  4   homepage               2366 non-null   object
#  5   imdb_id                7398 non-null   object
#  6   original_language      7398 non-null   object
#  7   original_title         7398 non-null   object
#  8   overview               7376 non-null   object
#  9   popularity             7398 non-null   float64
#  10  poster_path            7396 non-null   object
#  11  production_companies   6984 non-null   object
#  12  production_countries   7241 non-null   object
#  13  release_date           7397 non-null   object
#  14  runtime                7392 non-null   float64
#  15  spoken_languages       7336 non-null   object
#  16  status                 7396 non-null   object
#  17  tagline                5938 non-null   object
#  18  title                  7395 non-null   object
#  19  Keywords               6729 non-null   object
#  20  cast                   7372 non-null   object
#  21  crew                   7360 non-null   object
#  22  revenue                7398 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    5917
# budget                      0
# genres                     23
# homepage                 5032
# imdb_id                     0
# original_language           0
# original_title              0
# overview                   22
# popularity                  0
# poster_path                 2
# production_companies      414
# production_countries      157
# release_date                1
# runtime                     6
# spoken_languages           62
# status                      2
# tagline                  1460
# title                       3
# Keywords                  669
# cast                       26
# crew                       38
# revenue                     0
# dtype: int64

# %%
df.drop(['belongs_to_collection'], axis=1, inplace=True)
df.drop(['homepage'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# id                         0
# budget                     0
# genres                    23
# imdb_id                    0
# original_language          0
# original_title             0
# overview                  22
# popularity                 0
# poster_path                2
# production_companies     414
# production_countries     157
# release_date               1
# runtime                    6
# spoken_languages          62
# status                     2
# tagline                 1460
# title                      3
# Keywords                 669
# cast                      26
# crew                      38
# revenue                    0
# dtype: int64

# %%
df.corr()
# Out:
#                   id    budget  popularity   runtime   revenue
# id          1.000000  0.003845    0.004816  0.000077 -0.293925
# budget      0.003845  1.000000    0.340145  0.216251  0.450264
# popularity  0.004816  0.340145    1.000000  0.112664  0.273089
# runtime     0.000077  0.216251    0.112664  1.000000  0.134784
# revenue    -0.293925  0.450264    0.273089  0.134784  1.000000

# %% [markdown]
# ## EDA - Budget

# %%
sns.histplot(df["budget"], bins = 40)
# Out:
# <AxesSubplot:xlabel='budget', ylabel='Count'>

# %%
sns.scatterplot(x=df['budget'], y=df['revenue'])
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %% [markdown]
# ## EDA - Popularity

# %%
sns.histplot(df["popularity"], bins = 40)
# Out:
# <AxesSubplot:xlabel='popularity', ylabel='Count'>

# %%
sns.scatterplot(x=df['budget'], y=df['revenue'])
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %% [markdown]
# ## EDA - runtime

# %%
sns.histplot(df["runtime"], bins = 40)
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='Count'>

# %%
sns.scatterplot(x=df['runtime'], y=df['revenue'])
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='revenue'>

# %% [markdown]
# ## EDA - original_language

# %%
df["original_language"].unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id', 'ka', 'th', 'ca', 'bm', 'af', 'xx', 'kn', 'is'],
#       dtype=object)

# %%
sns.histplot(df["original_language"])
# Out:
# <AxesSubplot:xlabel='original_language', ylabel='Count'>

# %%
df_original_language = df.groupby("original_language").mean().revenue

# %%
X = df_original_language.index
Y = df_original_language.values

plt.plot(X,Y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
