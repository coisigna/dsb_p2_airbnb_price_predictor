# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df_train = pd.read_csv("datasets/JOB-A-THON/train.csv")

# %%
df_test = pd.read_csv("datasets/JOB-A-THON/test.csv")

# %%
df_sample = pd.read_csv("datasets/JOB-A-THON/sample.csv")

# %%
df_train
# Out:
#             ID  Age  Gender         Income     Balance  Vintage  \
# 0     84e2fcc9   36  Female       5L - 10L   563266.44        4
# 1     57fea15e   53  Female   Less than 5L   875572.11        2
# 2     8df34ef3   35  Female  More than 15L   701607.06        2
# 3     c5c0788b   43  Female  More than 15L  1393922.16        0
# 4     951d69c4   39  Female  More than 15L   893146.23        1
# ...        ...  ...     ...            ...         ...      ...
# 6645  a8216afd   61    Male       5L - 10L  1354526.19        4
# 6646  153a306b   42  Female       5L - 10L   596286.54        3
# 6647  d4075a95   29    Male   Less than 5L   979298.19        2
# 6648  5855b142   66  Female      10L - 15L   395233.65        3
# 6649  57b39511   37    Male  More than 15L   826947.27        1
#
#       Transaction_Status Product_Holdings  Credit_Card Credit_Category  \
# 0                      0                1            0         Average
# ...

# %%
df_test
# Out:
#             ID  Age  Gender         Income     Balance  Vintage  \
# 0     55480787   50  Female  More than 15L  1008636.39        2
# 1     9aededf2   36    Male       5L - 10L   341460.72        2
# 2     a5034a09   25  Female      10L - 15L   439460.10        0
# 3     b3256702   41    Male   Less than 5L    28581.93        0
# 4     dc28adb5   48    Male  More than 15L  1104540.03        2
# ...        ...  ...     ...            ...         ...      ...
# 2846  19e40adf   40  Female      10L - 15L  1338458.22        0
# 2847  52d5bc8d   48  Female  More than 15L  1448280.27        0
# 2848  f708121b   59    Male  More than 15L  1100555.64        3
# 2849  f008715d   34  Female       5L - 10L  1502818.92        2
# 2850  36b81f59   61  Female      10L - 15L   913787.73        0
#
#       Transaction_Status Product_Holdings  Credit_Card Credit_Category
# 0                      1                2            1         Average
# ...

# %%
df_sample
# Out:
#             ID  Is_Churn
# 0     55480787         1
# 1     9aededf2         1
# 2     a5034a09         1
# 3     b3256702         1
# 4     dc28adb5         1
# ...        ...       ...
# 2846  19e40adf         1
# 2847  52d5bc8d         1
# 2848  f708121b         1
# 2849  f008715d         1
# 2850  36b81f59         1
#
# [2851 rows x 2 columns]

# %%
df_test_sample = pd.merge(left = df_test, right = df_sample, left_on = "ID", right_on = "ID", how = "outer")

# %%
df_complete = df_train.append(df_test_sample).reset_index()
# Out:
# /var/folders/10/5nbnv2696vlgb605wf3g6wwh0000gn/T/ipykernel_4329/2094212991.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_complete = df_train.append(df_test_sample).reset_index()

# %%
df_complete = df_complete.drop("index", axis = 1)

# %%
df_complete
# Out:
#             ID  Age  Gender         Income     Balance  Vintage  \
# 0     84e2fcc9   36  Female       5L - 10L   563266.44        4
# 1     57fea15e   53  Female   Less than 5L   875572.11        2
# 2     8df34ef3   35  Female  More than 15L   701607.06        2
# 3     c5c0788b   43  Female  More than 15L  1393922.16        0
# 4     951d69c4   39  Female  More than 15L   893146.23        1
# ...        ...  ...     ...            ...         ...      ...
# 9496  19e40adf   40  Female      10L - 15L  1338458.22        0
# 9497  52d5bc8d   48  Female  More than 15L  1448280.27        0
# 9498  f708121b   59    Male  More than 15L  1100555.64        3
# 9499  f008715d   34  Female       5L - 10L  1502818.92        2
# 9500  36b81f59   61  Female      10L - 15L   913787.73        0
#
#       Transaction_Status Product_Holdings  Credit_Card Credit_Category  \
# 0                      0                1            0         Average
# ...

# %%
df_complete.shape
# Out:
# (9501, 11)

# %%
df_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9501 entries, 0 to 9500
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  9501 non-null   object
#  1   Age                 9501 non-null   int64
#  2   Gender              9501 non-null   object
#  3   Income              9501 non-null   object
#  4   Balance             9501 non-null   float64
#  5   Vintage             9501 non-null   int64
#  6   Transaction_Status  9501 non-null   int64
#  7   Product_Holdings    9501 non-null   object
#  8   Credit_Card         9501 non-null   int64
#  9   Credit_Category     9501 non-null   object
#  10  Is_Churn            9501 non-null   int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 816.6+ KB

# %%
df_complete.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Income', 'Balance', 'Vintage',
#        'Transaction_Status', 'Product_Holdings', 'Credit_Card',
#        'Credit_Category', 'Is_Churn'],
#       dtype='object')

# %%
df_complete.describe().T
# Out:
#                      count           mean            std   min        25%  \
# Age                 9501.0      41.166825       9.664752  21.0      34.00
# Balance             9501.0  806186.839248  518585.249119  63.0  395233.65
# Vintage             9501.0       2.241448       1.468193   0.0       1.00
# Transaction_Status  9501.0       0.513104       0.499855   0.0       0.00
# Credit_Card         9501.0       0.665719       0.471763   0.0       0.00
# Is_Churn            9501.0       0.461846       0.498568   0.0       0.00
#
#                           50%         75%         max
# Age                     40.00       47.00       72.00
# Balance             765196.38  1149418.44  2436615.81
# Vintage                  2.00        3.00        5.00
# Transaction_Status       1.00        1.00        1.00
# Credit_Card              1.00        1.00        1.00
# Is_Churn                 0.00        1.00        1.00

# %%
for i in df_complete.columns:
    print(i)
    print("---"*30)
    print(len(df_complete[i].unique()),df_complete[i].unique())
    print("---" *30)
# Out:
# ID
# ------------------------------------------------------------------------------------------
# 9501 ['84e2fcc9' '57fea15e' '8df34ef3' ... 'f708121b' 'f008715d' '36b81f59']
# ------------------------------------------------------------------------------------------
# Age
# ------------------------------------------------------------------------------------------
# 52 [36 53 35 43 39 31 56 41 60 32 40 33 37 47 28 30 45 66 62 34 42 38 52 54
#  27 68 58 59 25 26 48 29 44 67 49 63 55 46 65 57 23 50 51 71 69 61 64 24
#  22 70 72 21]
# ------------------------------------------------------------------------------------------
# Gender
# ------------------------------------------------------------------------------------------
# 2 ['Female' 'Male']
# ------------------------------------------------------------------------------------------
# Income
# ------------------------------------------------------------------------------------------
# ...

# %%
sns.pairplot(df_complete)

# %%
df_nums = df_complete._get_numeric_data()

# %%
for i in df_nums.columns:
    
    print(i)
    sns.kdeplot(df_nums[i].unique())
    plt.show()
# Out:
# Age
# Balance
# Vintage
# Transaction_Status
# Credit_Card
# Is_Churn

# %%
sns.kdeplot(df_complete["Age"].unique())
plt.show()

# %%
plt.bar(df_complete["Age"], df_complete["Balance"])
plt.show()

# %%
df_credit = df_complete[["Age","Gender","Income","Credit_Card","Credit_Category"]]

# %%
df_credit
# Out:
#       Age  Gender         Income  Credit_Card Credit_Category
# 0      36  Female       5L - 10L            0         Average
# 1      53  Female   Less than 5L            1            Poor
# 2      35  Female  More than 15L            0            Poor
# 3      43  Female  More than 15L            1            Poor
# 4      39  Female  More than 15L            1            Good
# ...   ...     ...            ...          ...             ...
# 9496   40  Female      10L - 15L            1            Poor
# 9497   48  Female  More than 15L            1         Average
# 9498   59    Male  More than 15L            1            Poor
# 9499   34  Female       5L - 10L            1            Poor
# 9500   61  Female      10L - 15L            1            Good
#
# [9501 rows x 5 columns]

# %%
df_complete.corr()
# Out:
#                          Age   Balance   Vintage  Transaction_Status  \
# Age                 1.000000  0.010935  0.021315            0.036753
# Balance             0.010935  1.000000 -0.020406           -0.006330
# Vintage             0.021315 -0.020406  1.000000           -0.026831
# Transaction_Status  0.036753 -0.006330 -0.026831            1.000000
# Credit_Card         0.004844 -0.022111  0.001343            0.001169
# Is_Churn            0.125261  0.036498  0.005396           -0.057233
#
#                     Credit_Card  Is_Churn
# Age                    0.004844  0.125261
# Balance               -0.022111  0.036498
# Vintage                0.001343  0.005396
# Transaction_Status     0.001169 -0.057233
# Credit_Card            1.000000  0.002606
# Is_Churn               0.002606  1.000000

# %%
for i in df_nums.columns:
    print(i)
    sns.histplot(df_complete[i])
    plt.show()
# Out:
# Age
# Balance
# Vintage
# Transaction_Status
# Credit_Card
# Is_Churn
