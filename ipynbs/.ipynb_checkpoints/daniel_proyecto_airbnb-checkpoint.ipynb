# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
df_madrid = pd.read_csv("madrid.csv")
df_madrid = pd.read_csv("malaga.csv")
df_madrid = pd.read_csv("madrid.csv")
df_madrid = pd.read_csv("madrid.csv")
df_madrid = pd.read_csv("madrid.csv")
df_madrid = pd.read_csv("madrid.csv")
df_madrid = pd.read_csv("madrid.csv")
df_madrid = pd.read_csv("madrid.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19300\4139607506.py in <module>
# ----> 1 df_madrid = pd.read_csv("madrid.csv")
#       2 df_madrid = pd.read_csv("madrid.csv")
#       3
#       4 df
#
# NameError: name 'pd' is not defined

# %%
columns_drop = ["listing_url", "scrape_id", "last_scraped", "description", "picture_url", "host_url", "host_about",
                "host_location", "name", "neighborhood_overview", "host_since", "host_thumbnail_url", "host_picture_url",
                "host_neighbourhood", "host_listings_count", "host_has_profile_pic", "bathrooms", "calendar_updated",
                "has_availability", "calendar_last_scraped", "number_of_reviews_ltm", "number_of_reviews_l30d",
                "first_review", "last_review", "review_scores_rating", "review_scores_accuracy", "review_scores_cleanliness",
                "review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value",
                "license", "calculated_host_listings_count_entire_homes", "calculated_host_listings_count_private_rooms",
                "calculated_host_listings_count_shared_rooms", "neighbourhood", "host_name", "calculated_host_listings_count"]

columns_maybe_drop = ["host_response_time", "host_response_rate", "host_acceptance_rate", "host_is_superhost",
                      "host_identity_verified", "minimum_minimum_nights", "minimum_minimum_nights", "maximum_minimum_nights",
                      "minimum_maximum_nights", "maximum_maximum_nights", "minimum_nights_avg_ntm", "maximum_nights_avg_ntm",
                      "availability_30", "availability_60", "availability_90"]

# %%
df.drop(columns = columns_drop + columns_maybe_drop, axis = 1, inplace = True)

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# id                               0.000000
# host_id                          0.000000
# host_total_listings_count        2.686308
# host_verifications               0.000000
# neighbourhood_cleansed           0.000000
# neighbourhood_group_cleansed     0.000000
# latitude                         0.000000
# longitude                        0.000000
# property_type                    0.000000
# room_type                        0.000000
# accommodates                     0.000000
# bathrooms_text                   0.147823
# bedrooms                         7.620553
# beds                             2.038944
# amenities                        0.000000
# price                            0.000000
# minimum_nights                   0.000000
# maximum_nights                   0.000000
# availability_365                 0.000000
# number_of_reviews                0.000000
# instant_bookable                 0.000000
# reviews_per_month               28.733816
# dtype: float64

# %%
# host_verifications: número de elementos en la lista
df["host_verifications"] = df["host_verifications"].apply(lambda x : len(json.loads((x.replace("'", '"')))) if x != "None" else np.nan)

# %%
# bathrooms_text: limpieza de columna

df["bathrooms_text"] = df["bathrooms_text"].apply(lambda x : x.split(" ")[0] if (type(x) == str) and ("bath" in x) else np.nan)

bath_map = {"Private" : 1, "Shared" : 0.5, "Half-bath" : 0.5}

df["bathrooms_text"] = df["bathrooms_text"].apply(lambda x : bath_map[x] if x in bath_map.keys() else float(x))

# %%
# amenities: número de elementos en la lista

list_amenities = list()

for num, x in enumerate(df["amenities"].values):
    try:
        list_amenities.append(len(json.loads((x.replace("'", '"')))))
        
    except:
        list_amenities.append(len(x.replace("'", '"').replace("\\", "")))
        
        
df["amenities"] = list_amenities

# %%
# Quito esta columna por la cantidad de NaN's, pero creo que si estuviera el modelo daría mejores resultados
# Se pueden llenar con KNNImputer

# df.drop("reviews_per_month", axis = 1, inplace = True)
df.dropna(inplace = True)

# %%
df
# Out:
#              id    host_id  host_total_listings_count  host_verifications  \
# 0          6369      13660                        1.0                 6.0
# 1         21853      83531                        2.0                 7.0
# 4         26825     114340                        1.0                 5.0
# 6         30320     130907                        3.0                 3.0
# 7         30959     132883                        1.0                 4.0
# ...         ...        ...                        ...                 ...
# 19467  48948030    9885245                       33.0                 5.0
# 19491  48977491  394669135                        0.0                 2.0
# 19493  48978809   34770530                        1.0                 2.0
# 19494  48980117    4294898                        2.0                 9.0
# 19500  48991692  236357316                        1.0                 2.0
#
#       neighbourhood_cleansed neighbourhood_group_cleansed  latitude  \
# 0             Hispanoamérica                    Chamartín  40.45724
# 1                   Cármenes                       Latina  40.40381
# 4                    Legazpi                   Arganzuela  40.38975
# 6                        Sol                       Centro  40.41476
# 7                Embajadores                       Centro  40.41259
# ...                      ...                          ...       ...
# 19467            Castillejos                       Tetuán  40.46234
# 19491                    Sol                       Centro  40.41913
# 19493               Almenara                       Tetuán  40.46816
# 19494               Justicia                       Centro  40.42207
# 19500                 Ventas                Ciudad Lineal  40.43080
#
#        longitude                      property_type        room_type  ...  \
# 0       -3.67688          Private room in apartment     Private room  ...
# 1       -3.74130          Private room in apartment     Private room  ...
# 4       -3.69018              Private room in house     Private room  ...
# 6       -3.70418                   Entire apartment  Entire home/apt  ...
# 7       -3.70105                        Entire loft  Entire home/apt  ...
# ...          ...                                ...              ...  ...
# 19467   -3.69516                   Entire apartment  Entire home/apt  ...
# 19491   -3.70173          Private room in apartment     Private room  ...
# 19493   -3.68873  Private room in bed and breakfast     Private room  ...
# 19494   -3.69930                   Entire apartment  Entire home/apt  ...
# 19500   -3.65934                   Entire apartment  Entire home/apt  ...
#
#        bedrooms  beds  amenities   price  minimum_nights maximum_nights  \
# 0           1.0   1.0         18  $60.00               1           1125
# 1           1.0   1.0         28  $31.00               4             40
# 4           1.0   1.0         14  $26.00               2           1125
# 6           1.0   2.0          8  $65.00               5            180
# 7           1.0   1.0         11  $54.00               3            730
# ...         ...   ...        ...     ...             ...            ...
# 19467       3.0   4.0         22  $62.00               1           1125
# 19491       1.0   2.0         27  $60.00               1           1125
# 19493       1.0   1.0         17  $25.00               1              7
# 19494       1.0   1.0         29  $44.00               2           1125
# 19500       2.0   2.0         21  $70.00               1           1125
#
#        availability_365  number_of_reviews  instant_bookable  \
# 0                   180                 78                 f
# 1                   364                 33                 f
# 4                   365                149                 f
# 6                   351                170                 f
# 7                     0                  8                 f
# ...                 ...                ...               ...
# 19467               360                  1                 f
# 19491               158                  2                 t
# 19493               175                  1                 t
# 19494               331                  1                 f
# 19500                89                  1                 f
#
#        reviews_per_month
# 0                   0.58
# 1                   0.42
# 4                   1.12
# 6                   1.29
# 7                   0.11
# ...                  ...
# 19467               1.00
# 19491               2.00
# 19493               1.00
# 19494               1.00
# 19500               1.00
#
# [12432 rows x 22 columns]

# %%
df_num = df._get_numeric_data()
df_num
# Out:
#              id    host_id  host_total_listings_count  host_verifications  \
# 0          6369      13660                        1.0                 6.0
# 1         21853      83531                        2.0                 7.0
# 4         26825     114340                        1.0                 5.0
# 6         30320     130907                        3.0                 3.0
# 7         30959     132883                        1.0                 4.0
# ...         ...        ...                        ...                 ...
# 19467  48948030    9885245                       33.0                 5.0
# 19491  48977491  394669135                        0.0                 2.0
# 19493  48978809   34770530                        1.0                 2.0
# 19494  48980117    4294898                        2.0                 9.0
# 19500  48991692  236357316                        1.0                 2.0
#
#        latitude  longitude  accommodates  bathrooms_text  bedrooms  beds  \
# 0      40.45724   -3.67688             2             1.0       1.0   1.0
# 1      40.40381   -3.74130             1             1.0       1.0   1.0
# 4      40.38975   -3.69018             1             1.0       1.0   1.0
# 6      40.41476   -3.70418             2             1.0       1.0   2.0
# 7      40.41259   -3.70105             2             1.0       1.0   1.0
# ...         ...        ...           ...             ...       ...   ...
# 19467  40.46234   -3.69516             8             1.5       3.0   4.0
# 19491  40.41913   -3.70173             4             1.0       1.0   2.0
# 19493  40.46816   -3.68873             2             1.0       1.0   1.0
# 19494  40.42207   -3.69930             4             1.0       1.0   1.0
# 19500  40.43080   -3.65934             3             2.0       2.0   2.0
#
#        amenities  minimum_nights  maximum_nights  availability_365  \
# 0             18               1            1125               180
# 1             28               4              40               364
# 4             14               2            1125               365
# 6              8               5             180               351
# 7             11               3             730                 0
# ...          ...             ...             ...               ...
# 19467         22               1            1125               360
# 19491         27               1            1125               158
# 19493         17               1               7               175
# 19494         29               2            1125               331
# 19500         21               1            1125                89
#
#        number_of_reviews  reviews_per_month
# 0                     78               0.58
# 1                     33               0.42
# 4                    149               1.12
# 6                    170               1.29
# 7                      8               0.11
# ...                  ...                ...
# 19467                  1               1.00
# 19491                  2               2.00
# 19493                  1               1.00
# 19494                  1               1.00
# 19500                  1               1.00
#
# [12432 rows x 16 columns]

# %%
# Agrego la columna id para después hacer pd.merge()

df_cat = df.drop(df_num.columns, axis = 1)
df_cat = pd.concat([df_cat, df_num[["id"]]], axis = 1)
df_cat
# Out:
#       neighbourhood_cleansed neighbourhood_group_cleansed  \
# 0             Hispanoamérica                    Chamartín
# 1                   Cármenes                       Latina
# 4                    Legazpi                   Arganzuela
# 6                        Sol                       Centro
# 7                Embajadores                       Centro
# ...                      ...                          ...
# 19467            Castillejos                       Tetuán
# 19491                    Sol                       Centro
# 19493               Almenara                       Tetuán
# 19494               Justicia                       Centro
# 19500                 Ventas                Ciudad Lineal
#
#                            property_type        room_type   price  \
# 0              Private room in apartment     Private room  $60.00
# 1              Private room in apartment     Private room  $31.00
# 4                  Private room in house     Private room  $26.00
# 6                       Entire apartment  Entire home/apt  $65.00
# 7                            Entire loft  Entire home/apt  $54.00
# ...                                  ...              ...     ...
# 19467                   Entire apartment  Entire home/apt  $62.00
# 19491          Private room in apartment     Private room  $60.00
# 19493  Private room in bed and breakfast     Private room  $25.00
# 19494                   Entire apartment  Entire home/apt  $44.00
# 19500                   Entire apartment  Entire home/apt  $70.00
#
#       instant_bookable        id
# 0                    f      6369
# 1                    f     21853
# 4                    f     26825
# 6                    f     30320
# 7                    f     30959
# ...                ...       ...
# 19467                f  48948030
# 19491                t  48977491
# 19493                t  48978809
# 19494                f  48980117
# 19500                f  48991692
#
# [12432 rows x 7 columns]

# %%
# Decido quedarme solo con "neighbourhood_group_cleansed"

df_cat.drop(["neighbourhood_cleansed"], axis = 1, inplace = True)

df_cat
# Out:
#       neighbourhood_group_cleansed                      property_type  \
# 0                        Chamartín          Private room in apartment
# 1                           Latina          Private room in apartment
# 4                       Arganzuela              Private room in house
# 6                           Centro                   Entire apartment
# 7                           Centro                        Entire loft
# ...                            ...                                ...
# 19467                       Tetuán                   Entire apartment
# 19491                       Centro          Private room in apartment
# 19493                       Tetuán  Private room in bed and breakfast
# 19494                       Centro                   Entire apartment
# 19500                Ciudad Lineal                   Entire apartment
#
#              room_type   price instant_bookable        id
# 0         Private room  $60.00                f      6369
# 1         Private room  $31.00                f     21853
# 4         Private room  $26.00                f     26825
# 6      Entire home/apt  $65.00                f     30320
# 7      Entire home/apt  $54.00                f     30959
# ...                ...     ...              ...       ...
# 19467  Entire home/apt  $62.00                f  48948030
# 19491     Private room  $60.00                t  48977491
# 19493     Private room  $25.00                t  48978809
# 19494  Entire home/apt  $44.00                f  48980117
# 19500  Entire home/apt  $70.00                f  48991692
#
# [12432 rows x 6 columns]

# %%
# price: limpieza de columna
df_cat["price"] = df_cat["price"].apply(lambda x : float(x.strip("$").replace(",", "")))

# %%
# instant_bookable: transformar a 0 y 1
df_cat["instant_bookable"] = df_cat["instant_bookable"].apply(lambda x : 0 if x == "f" else 1)

# %%
# room_type: eliminar "Hotel room" y transformar a dummies

df_cat = df_cat[df_cat["room_type"] != "Hotel room"]

df_cat = pd.concat([df_cat, pd.get_dummies(data = df_cat["room_type"])], axis = 1).drop("room_type", axis = 1)

# %%
df_cat
# Out:
#       neighbourhood_group_cleansed                      property_type  price  \
# 0                        Chamartín          Private room in apartment   60.0
# 1                           Latina          Private room in apartment   31.0
# 4                       Arganzuela              Private room in house   26.0
# 6                           Centro                   Entire apartment   65.0
# 7                           Centro                        Entire loft   54.0
# ...                            ...                                ...    ...
# 19467                       Tetuán                   Entire apartment   62.0
# 19491                       Centro          Private room in apartment   60.0
# 19493                       Tetuán  Private room in bed and breakfast   25.0
# 19494                       Centro                   Entire apartment   44.0
# 19500                Ciudad Lineal                   Entire apartment   70.0
#
#        instant_bookable        id  Entire home/apt  Private room  Shared room
# 0                     0      6369                0             1            0
# 1                     0     21853                0             1            0
# 4                     0     26825                0             1            0
# 6                     0     30320                1             0            0
# 7                     0     30959                1             0            0
# ...                 ...       ...              ...           ...          ...
# 19467                 0  48948030                1             0            0
# 19491                 1  48977491                0             1            0
# 19493                 1  48978809                0             1            0
# 19494                 0  48980117                1             0            0
# 19500                 0  48991692                1             0            0
#
# [12336 rows x 8 columns]

# %%
# property_type está representada port la columnas dummies de room_type

df_cat.drop("property_type", axis = 1, inplace = True)

# %%
# Uso el LabelEncoder para transformarlo a números sin ningún tipo de relación u orden

from sklearn.preprocessing import LabelEncoder

neighbourhood_group_encoder = LabelEncoder()
df_cat["neighbourhood_group_cleansed"] = neighbourhood_group_encoder.fit_transform(df_cat["neighbourhood_group_cleansed"])

# %%
df = pd.merge(left = df_num, right = df_cat, on = "id")

df
# Out:
#              id    host_id  host_total_listings_count  host_verifications  \
# 0          6369      13660                        1.0                 6.0
# 1         21853      83531                        2.0                 7.0
# 2         26825     114340                        1.0                 5.0
# 3         30320     130907                        3.0                 3.0
# 4         30959     132883                        1.0                 4.0
# ...         ...        ...                        ...                 ...
# 12331  48948030    9885245                       33.0                 5.0
# 12332  48977491  394669135                        0.0                 2.0
# 12333  48978809   34770530                        1.0                 2.0
# 12334  48980117    4294898                        2.0                 9.0
# 12335  48991692  236357316                        1.0                 2.0
#
#        latitude  longitude  accommodates  bathrooms_text  bedrooms  beds  ...  \
# 0      40.45724   -3.67688             2             1.0       1.0   1.0  ...
# 1      40.40381   -3.74130             1             1.0       1.0   1.0  ...
# 2      40.38975   -3.69018             1             1.0       1.0   1.0  ...
# 3      40.41476   -3.70418             2             1.0       1.0   2.0  ...
# 4      40.41259   -3.70105             2             1.0       1.0   1.0  ...
# ...         ...        ...           ...             ...       ...   ...  ...
# 12331  40.46234   -3.69516             8             1.5       3.0   4.0  ...
# 12332  40.41913   -3.70173             4             1.0       1.0   2.0  ...
# 12333  40.46816   -3.68873             2             1.0       1.0   1.0  ...
# 12334  40.42207   -3.69930             4             1.0       1.0   1.0  ...
# 12335  40.43080   -3.65934             3             2.0       2.0   2.0  ...
#
#        maximum_nights  availability_365  number_of_reviews  reviews_per_month  \
# 0                1125               180                 78               0.58
# 1                  40               364                 33               0.42
# 2                1125               365                149               1.12
# 3                 180               351                170               1.29
# 4                 730                 0                  8               0.11
# ...               ...               ...                ...                ...
# 12331            1125               360                  1               1.00
# 12332            1125               158                  2               2.00
# 12333               7               175                  1               1.00
# 12334            1125               331                  1               1.00
# 12335            1125                89                  1               1.00
#
#        neighbourhood_group_cleansed  price  instant_bookable  Entire home/apt  \
# 0                                 4   60.0                 0                0
# 1                                 9   31.0                 0                0
# 2                                 0   26.0                 0                0
# 3                                 3   65.0                 0                1
# 4                                 3   54.0                 0                1
# ...                             ...    ...               ...              ...
# 12331                            16   62.0                 0                1
# 12332                             3   60.0                 1                0
# 12333                            16   25.0                 1                0
# 12334                             3   44.0                 0                1
# 12335                             6   70.0                 0                1
#
#        Private room  Shared room
# 0                 1            0
# 1                 1            0
# 2                 1            0
# 3                 0            0
# 4                 0            0
# ...             ...          ...
# 12331             0            0
# 12332             1            0
# 12333             1            0
# 12334             0            0
# 12335             0            0
#
# [12336 rows x 22 columns]

# %% [markdown]
# ### Outliers

# %%
df
# Out:
#              id    host_id  host_total_listings_count  host_verifications  \
# 0          6369      13660                        1.0                 6.0
# 1         21853      83531                        2.0                 7.0
# 2         26825     114340                        1.0                 5.0
# 3         30320     130907                        3.0                 3.0
# 4         30959     132883                        1.0                 4.0
# ...         ...        ...                        ...                 ...
# 12331  48948030    9885245                       33.0                 5.0
# 12332  48977491  394669135                        0.0                 2.0
# 12333  48978809   34770530                        1.0                 2.0
# 12334  48980117    4294898                        2.0                 9.0
# 12335  48991692  236357316                        1.0                 2.0
#
#        latitude  longitude  accommodates  bathrooms_text  bedrooms  beds  ...  \
# 0      40.45724   -3.67688             2             1.0       1.0   1.0  ...
# 1      40.40381   -3.74130             1             1.0       1.0   1.0  ...
# 2      40.38975   -3.69018             1             1.0       1.0   1.0  ...
# 3      40.41476   -3.70418             2             1.0       1.0   2.0  ...
# 4      40.41259   -3.70105             2             1.0       1.0   1.0  ...
# ...         ...        ...           ...             ...       ...   ...  ...
# 12331  40.46234   -3.69516             8             1.5       3.0   4.0  ...
# 12332  40.41913   -3.70173             4             1.0       1.0   2.0  ...
# 12333  40.46816   -3.68873             2             1.0       1.0   1.0  ...
# 12334  40.42207   -3.69930             4             1.0       1.0   1.0  ...
# 12335  40.43080   -3.65934             3             2.0       2.0   2.0  ...
#
#        maximum_nights  availability_365  number_of_reviews  reviews_per_month  \
# 0                1125               180                 78               0.58
# 1                  40               364                 33               0.42
# 2                1125               365                149               1.12
# 3                 180               351                170               1.29
# 4                 730                 0                  8               0.11
# ...               ...               ...                ...                ...
# 12331            1125               360                  1               1.00
# 12332            1125               158                  2               2.00
# 12333               7               175                  1               1.00
# 12334            1125               331                  1               1.00
# 12335            1125                89                  1               1.00
#
#        neighbourhood_group_cleansed  price  instant_bookable  Entire home/apt  \
# 0                                 4   60.0                 0                0
# 1                                 9   31.0                 0                0
# 2                                 0   26.0                 0                0
# 3                                 3   65.0                 0                1
# 4                                 3   54.0                 0                1
# ...                             ...    ...               ...              ...
# 12331                            16   62.0                 0                1
# 12332                             3   60.0                 1                0
# 12333                            16   25.0                 1                0
# 12334                             3   44.0                 0                1
# 12335                             6   70.0                 0                1
#
#        Private room  Shared room
# 0                 1            0
# 1                 1            0
# 2                 1            0
# 3                 0            0
# 4                 0            0
# ...             ...          ...
# 12331             0            0
# 12332             1            0
# 12333             1            0
# 12334             0            0
# 12335             0            0
#
# [12336 rows x 22 columns]

# %%
df["bathrooms_text"] = df["bathrooms_text"].apply(lambda x : np.ceil(x))

# %%
# Eliminé outliers solo viendo las gráficas
# Elimino alrededor de 4000 filas (muchísimo)

df = df[df["accommodates"] <= 8]
df = df[df["bathrooms_text"].between(1, 2)]
df = df[df["bedrooms"] <= 4]
df = df[df["beds"].between(1, 5)]
df = df[df["amenities"] <= 50]
df = df[df["minimum_nights"] <= 30]
df = df[df["number_of_reviews"] <= 300]
df = df[df["reviews_per_month"] <= 8]
df = df[df["price"] <= 400]
# df = df[df["host_total_listings_count"] <= 40]

# %%
# Elimono "Shared room" por el desbalance, casí no aparace en comparación a los otros

df.drop("Shared room", axis = 1, inplace = True)

# %% [markdown]
# ### Normalizar

# %%
from sklearn.preprocessing import MinMaxScaler

x_scaler = MinMaxScaler()
df[df.drop("price", axis = 1).columns] = x_scaler.fit_transform(df[df.drop("price", axis = 1).columns])

y_scaler = MinMaxScaler()
df["price"] = y_scaler.fit_transform(df[["price"]]).flatten()

# %%
df.drop(["host_id", "id", "latitude", "longitude"], axis = 1, inplace = True)

# %%
df.drop(["instant_bookable", "host_verifications"], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['host_total_listings_count', 'accommodates', 'bathrooms_text',
#        'bedrooms', 'beds', 'amenities', 'minimum_nights', 'maximum_nights',
#        'availability_365', 'number_of_reviews', 'reviews_per_month',
#        'neighbourhood_group_cleansed', 'price', 'Entire home/apt',
#        'Private room'],
#       dtype='object')

# %%
X = df.drop(["price"], axis = 1)
y = df["price"]

print(X.shape, y.shape)
# Out:
# (10634, 14) (10634,)

# %% [markdown]
# ### Train, Test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

print(f"X_train: {X_train.shape} | y_train: {y_train.shape}")
print(f"X_test: {X_test.shape} | y_test: {y_test.shape}")
# Out:
# X_train: (7443, 14) | y_train: (7443,)
# X_test: (3191, 14) | y_test: (3191,)

# %% [markdown]
# ### Modelos y Métricas

# %%
# Modelos
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Métricas
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
# %%time

modelos = [LinearRegression(), KNeighborsRegressor(), DecisionTreeRegressor(),
           RandomForestRegressor(), SVR(), AdaBoostRegressor(), GradientBoostingRegressor()]

metricas = list() 

for model in modelos:
    
    # fit
    model.fit(X_train, y_train)
    
    # predict
    yhat = model.predict(X_test)
    
    # metrics
    r2 = r2_score(y_test, yhat)
    mse = mean_squared_error(y_test, yhat)
    
    metricas.append([str(model), r2, mse, model])
    
df_metricas = pd.DataFrame(data = metricas, columns = ["model_name", "r2", "mse", "model"])

df_metricas.sort_values(by = "r2", ascending = False)
# Out:
# CPU times: total: 2.66 s
# Wall time: 7.4 s
#                     model_name        r2       mse  \
# 6  GradientBoostingRegressor()  0.488335  0.007667
# 3      RandomForestRegressor()  0.456601  0.008143
# 0           LinearRegression()  0.420241  0.008688
# 4                        SVR()  0.393449  0.009089
# 1        KNeighborsRegressor()  0.365169  0.009513
# 2      DecisionTreeRegressor() -0.084649  0.016253
# 5          AdaBoostRegressor() -0.605144  0.024053
#
#                                                model
# 6  ([DecisionTreeRegressor(criterion='friedman_ms...
# 3  (DecisionTreeRegressor(max_features=1.0, rando...
# 0                                 LinearRegression()
# 4                                              SVR()
# 1                              KNeighborsRegressor()
# 2                            DecisionTreeRegressor()
# 5  (DecisionTreeRegressor(max_depth=3, random_sta...

# %%
modelo = df_metricas["model"][3]

modelo
# Out:
# RandomForestRegressor()

# %%
importances = np.argsort(modelo.feature_importances_)[::-1]

for i in importances:
    
    print(i, modelo.feature_importances_[i]*100, df.drop("price", axis = 1).columns[i])
# Out:
# 12 22.528872481545182 Entire home/apt
# 10 12.531425762021502 reviews_per_month
# 5 8.42615627690848 amenities
# 8 7.292162632910696 availability_365
# 3 7.102467761036882 bedrooms
# 9 6.299378529382979 number_of_reviews
# 11 6.217221444492185 neighbourhood_group_cleansed
# 0 5.981613585357366 host_total_listings_count
# 7 5.7820763444307435 maximum_nights
# 2 5.392996554207869 bathrooms_text
# 1 5.2446438016042345 accommodates
# 6 4.945929341575362 minimum_nights
# 4 2.185503228161992 beds
# 13 0.06955225636452984 Private room

# %%
modelo = df_metricas["model"][6]

importances = np.argsort(modelo.feature_importances_)[::-1]

for i in importances:
    
    print(i, modelo.feature_importances_[i]*100, df.drop("price", axis = 1).columns[i])
# Out:
# 12 27.23518698235677 Entire home/apt
# 1 25.804491256463912 accommodates
# 3 12.510177158317374 bedrooms
# 10 12.089722943423936 reviews_per_month
# 2 7.311652040706584 bathrooms_text
# 11 3.876467675758652 neighbourhood_group_cleansed
# 0 3.4977432613174027 host_total_listings_count
# 6 2.024057911058154 minimum_nights
# 8 1.623205900298973 availability_365
# 5 1.2222372272440647 amenities
# 7 1.0729991421839498 maximum_nights
# 9 1.0355919905501565 number_of_reviews
# 4 0.6684631794026807 beds
# 13 0.02800333091737395 Private room

# %%
y_test_inv = y_scaler.inverse_transform([y_test]).flatten()
yhat_inv = y_scaler.inverse_transform([yhat]).flatten()


r2 = r2_score(y_test_inv, yhat_inv)
mse = mean_squared_error(y_test_inv, yhat_inv)

print(r2, mse)
# Out:
# 0.48833513281964414 1178.1818442813062

# %%
# %%time

# from sklearn.model_selection import GridSearchCV

# # Modelo
# model = RandomForestRegressor()

# # Parametros a iterar
# params = {"n_estimators" : [i for i in range(100, 1001, 50)],
#           "max_depth"    : [8, 10, 12, 14, 16],
#           "max_features" : ["log2", "sqrt"]}

# # Metricas
# scorers = {"r2", "neg_mean_squared_error"}

# #GridSearchCV
# grid_solver = GridSearchCV(estimator  = model, 
#                            param_grid = params, 
#                            scoring    = scorers,
#                            cv         = 10,
#                            refit      = "r2",
#                            n_jobs     = -1, 
#                            verbose    = 2)

# # Resultados
# model_result = grid_solver.fit(X_train, y_train)

# %%
# model_result.best_estimator_

# %%
# model_result.cv_results_["mean_test_r2"].max()

# %%
# model_result.cv_results_

# %%
# model_result.best_score_

# %%
# %%time

# from sklearn.model_selection import GridSearchCV

# # Modelo
# model = GradientBoostingRegressor()

# # Parametros a iterar
# params = {"n_estimators"  : [i for i in range(100, 1001, 50)],
#           "max_depth"     : [8, 10, 12, 14, 16],
#           "max_features"  : ["log2", "sqrt"],
#           "learning_rate" : [1 / (10**i) for i in range(1, 5)]}

# # Metricas
# scorers = {"r2", "neg_mean_squared_error"}

# #GridSearchCV
# grid_solver = GridSearchCV(estimator  = model, 
#                            param_grid = params, 
#                            scoring    = scorers,
#                            cv         = 10,
#                            refit      = "r2",
#                            n_jobs     = -1, 
#                            verbose    = 2)

# # Resultados
# model_result = grid_solver.fit(X_train, y_train)

# %%
# model_result.best_estimator_, model_result.best_score_

# %%
import pickle


with open("model_gbr.sav", "wb") as file:
    pickle.dump(df_metricas["model"][6], file)

# %%
with open("model_gbr.sav", "rb") as file:
    model = pickle.load(file)

# %%
y_scaler.inverse_transform([model.predict([[round(x, 4) for x in X_test.iloc[0, :].values]])])
# Out:
# C:\Users\danie\anaconda3\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# array([[28.89435491]])
